# %%
# !pip install gmaps
# Out:
# Collecting gmaps
#   Using cached gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (7.16.1)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 8.7 MB/s eta 0:00:01
# Requirement already satisfied: traitlets>=4.3.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (4.3.3)
# Collecting geojson>=2.0.0
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: pygments in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (2.7.1)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (47.1.1.post20200604)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6"
#   Downloading jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 22.3 MB/s eta 0:00:01
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 42.6 MB/s eta 0:00:01
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.8)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->gmaps) (0.6.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: tornado>=4.2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: jupyter-client in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (19.0.2)
# Requirement already satisfied: Send2Trash in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.2.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.0.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.3)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: bleach in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.3.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.1)
# Requirement already satisfied: async-generator in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076096 sha256=9fc59fc7f6d60b9d6798ecd6afee5f935596f7fef7e1f4e742e89c3a916d389c
#   Stored in directory: /Users/lineafuller/Library/Caches/pip/wheels/46/48/5e/7fd28c7635ca35440a00b8a06b321febdd0b12d862ddac8659
# Successfully built gmaps
# Installing collected packages: jupyterlab-widgets, widgetsnbextension, ipywidgets, geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0 ipywidgets-7.6.5 jupyterlab-widgets-1.0.2 widgetsnbextension-3.5.2

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
# WeatherPy into DataFrame
weather_csv = "WeatherPy.csv"
weather_df = pd.read_csv(weather_csv)

weather_df
# Out:
#             City      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0       Galesong  -5.3166  119.3661     77.02        80          71
# 1           Teno -34.8667  -71.1833     74.75        43           0
# 2         Castro -24.7911  -50.0119     62.13        94           3
# 3          Igrim  63.1906   64.4162     21.38        74         100
# 4      Busselton -33.6500  115.3333     53.04        65           0
# ..           ...      ...       ...       ...       ...         ...
# 549    Egvekinot  66.3167 -179.1667     10.69        85          51
# 550  Ulaanbaatar  47.9077  106.8832      5.13        85           0
# 551    Yokadouma   3.5167   15.0500     71.44        90          93
# 552  Santa Marta  11.2408  -74.1990     86.34        82          55
# 553  Dicabisagan  17.0818  122.4157     77.70        88          97
#
#      Wind Speed Country        Date
# 0          3.69      ID  1636498341
# 1         10.36      CL  1636498342
# 2          9.35      BR  1636498342
# 3         12.91      RU  1636498343
# 4          8.25      AU  1636498343
# ..          ...     ...         ...
# 549        6.29      RU  1636498702
# 550        4.47      MN  1636498702
# 551        0.67      CM  1636498703
# 552       12.55      CO  1636498561
# 553        4.59      PH  1636498704
#
# [554 rows x 9 columns]

# %%
# Configure gmpas
gmaps.configure(g_key)

# Store Latitude and Longitude in locations and convert to float
locations= weather_df[["Lat", "Lon"]].astype(float)
humidity = weather_df["Humidity"].astype(float)

# Plot heatmap
figure = gmaps.figure()

# Create heat layer
heatmap = gmaps.heatmap_layer(locations, weights=humidity,
                              dissipating =False, max_intensity=10, point_radius=1)
# Add Layer
figure.add_layer(heatmap)

# Display figure
figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Check for Null values
weather_df.isnull().values.any()

#Locate Null values
weather_df.isnull().sum()

# Drop Null values
clean_weather_df = weather_df.dropna()
clean_weather_df
# Out:
#             City      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0       Galesong  -5.3166  119.3661     77.02        80          71
# 1           Teno -34.8667  -71.1833     74.75        43           0
# 2         Castro -24.7911  -50.0119     62.13        94           3
# 3          Igrim  63.1906   64.4162     21.38        74         100
# 4      Busselton -33.6500  115.3333     53.04        65           0
# ..           ...      ...       ...       ...       ...         ...
# 549    Egvekinot  66.3167 -179.1667     10.69        85          51
# 550  Ulaanbaatar  47.9077  106.8832      5.13        85           0
# 551    Yokadouma   3.5167   15.0500     71.44        90          93
# 552  Santa Marta  11.2408  -74.1990     86.34        82          55
# 553  Dicabisagan  17.0818  122.4157     77.70        88          97
#
#      Wind Speed Country        Date
# 0          3.69      ID  1636498341
# 1         10.36      CL  1636498342
# 2          9.35      BR  1636498342
# 3         12.91      RU  1636498343
# 4          8.25      AU  1636498343
# ..          ...     ...         ...
# 549        6.29      RU  1636498702
# 550        4.47      MN  1636498702
# 551        0.67      CM  1636498703
# 552       12.55      CO  1636498561
# 553        4.59      PH  1636498704
#
# [550 rows x 9 columns]

# %%
#Filter cities based on ideal weather condition.

# Ideal temperature: A max temperature lower than 80 degrees but higher than 70.
filtered_weather_df = clean_weather_df.loc[(clean_weather_df["Max Temp"] > 70) & (clean_weather_df["Max Temp"] <80)]

# Ideal Wind Speed: Less than 10
filtered_weather_df = clean_weather_df.loc[clean_weather_df["Wind Speed"] <10]

# Ideal Cloudiness: Zero cloudiness.
filtered_weather_df = clean_weather_df.loc[clean_weather_df["Cloudiness"] == 0]

# %%
filtered_weather_df
# Out:
#                           City      Lat       Lon  Max Temp  Humidity  \
# 1                         Teno -34.8667  -71.1833     74.75        43
# 4                    Busselton -33.6500  115.3333     53.04        65
# 11                     Ushuaia -54.8000  -68.3000     65.86        34
# 19                      Vicuña -30.0319  -70.7081     73.78        49
# 30                        Lata  40.1629   -8.3327     56.05        73
# 35                 Provideniya  64.3833 -173.3000     19.51        73
# 36                 East London -33.0153   27.9116     60.19        85
# 39                   Cape Town -33.9258   18.4232     59.11        78
# 76                   Geraldton -28.7667  114.6000     54.12        94
# 98              Guerrero Negro  27.9769 -114.0611     68.16        66
# 114               Punta Arenas -53.1500  -70.9167     69.91        19
# 119                     Bakloh  32.4667   75.9167     53.91        28
# 120                      Aswān  24.0934   32.9070     76.30        22
# 142                   Kurisove  46.9695   30.9591     36.05        64
# 158             Port Elizabeth -33.9180   25.5701     53.89        94
# 163                      Pisco -13.7000  -76.2167     68.05        73
# 178                     Rawson -43.3002  -65.1023     60.04        42
# 195                      Khāsh  28.2211   61.2158     49.46        53
# 214                   Behshahr  36.6923   53.5526     53.73        42
# 247                      Saýat  38.7839   63.8803     35.47        73
# 252                 Hammerfest  70.6634   23.6821     27.05        74
# 282              Villarrobledo  39.2699   -2.6012     46.78        68
# 296                      Jumla  29.2747   82.1838     41.76        35
# 304         Comodoro Rivadavia -45.8667  -67.5000     84.06        18
# 305                    Sakakah  29.9697   40.2064     58.57        17
# 309                   Jinchang  38.4953  102.1739     28.17        40
# 314                      Minna   9.6139    6.5569     80.31        83
# 318                    Baghdad  33.3406   44.4009     55.31        41
# 333                     Gashua  12.8710   11.0482     81.59        16
# 341                      Kumul  42.8000   93.4500     25.23        56
# 344            Tiznit Province  29.5833   -9.5000     55.13        59
# 347                    Xuchang  34.0167  113.8167     49.08        46
# 349                      Lampa -33.2833  -70.9000     72.43        43
# 364                 Portalegre  39.2938   -7.4312     49.50        62
# 372                     Baiyin  36.5583  104.2081     14.88        34
# 381             Bobo-Dioulasso  11.1771   -4.2979     84.65        58
# 399               Saint-Pierre -21.3393   55.4781     73.08        66
# 406                Santa Maria -29.6842  -53.8069     74.50        43
# 421                  Valadares  41.1474   -7.9812     54.48        76
# 444                      Ancud -41.8697  -73.8203     62.13        76
# 459                     Naples  40.8333   14.2500     68.05        79
# 475  Arrondissement d'Arcachon  44.5875   -1.0519     37.72        93
# 485                    Zhangye  38.9342  100.4517     20.44        56
# 489                San Ignacio  17.1561  -89.0714     84.34        51
# 499               Río Gallegos -51.6226  -69.2181     84.25         5
# 532                     Tanout  14.9709    8.8879     82.58        15
# 539                  Nantucket  41.2835  -70.0995     56.97        90
# 541                       Maun -19.9833   23.4167     80.56        36
# 546                   Dongying  37.4564  118.4856     37.44        71
# 550                Ulaanbaatar  47.9077  106.8832      5.13        85
#
#      Cloudiness  Wind Speed Country        Date
# 1             0       10.36      CL  1636498342
# 4             0        8.25      AU  1636498343
# 11            0       17.27      AR  1636498349
# 19            0        5.30      CL  1636498354
# 30            0        3.22      PT  1636498363
# 35            0        4.47      RU  1636498367
# 36            0        8.14      ZA  1636498368
# 39            0        5.75      ZA  1636498283
# 76            0        5.75      AU  1636498394
# 98            0       21.81      MX  1636498408
# 114           0       14.97      CL  1636498203
# 119           0        7.20      IN  1636498420
# 120           0       11.50      EG  1636498420
# 142           0       12.68      UA  1636498434
# 158           0        3.44      ZA  1636498446
# 163           0       21.85      PE  1636498450
# 178           0       26.84      AR  1636498459
# 195           0        4.65      IR  1636498470
# 214           0        5.70      IR  1636498483
# 247           0        5.97      TM  1636498504
# 252           0        3.44      NO  1636498508
# 282           0        9.04      ES  1636498527
# 296           0        5.03      NP  1636498536
# 304           0       17.27      AR  1636498541
# 305           0        4.99      SA  1636498542
# 309           0        1.59      CN  1636498545
# 314           0        4.61      NG  1636498548
# 318           0        2.30      IQ  1636498466
# 333           0        8.61      NG  1636498559
# 341           0        5.17      CN  1636498565
# 344           0        0.81      MA  1636498567
# 347           0        9.51      CN  1636498569
# 349           0       16.11      CL  1636498569
# 364           0        4.50      PT  1636498578
# 372           0        2.28      CN  1636498584
# 381           0        4.61      BF  1636498508
# 399           0        4.61      RE  1636498600
# 406           0        6.91      BR  1636498605
# 421           0        4.50      PT  1636498615
# 444           0       12.41      CL  1636498630
# 459           0        5.99      IT  1636498478
# 475           0        2.30      FR  1636498650
# 485           0        1.79      CN  1636498657
# 489           0        6.91      BZ  1636498661
# 499           0       26.46      AR  1636498612
# 532           0        7.61      NE  1636498690
# 539           0       12.01      US  1636498695
# 541           0        4.61      BW  1636498696
# 546           0        9.80      CN  1636498700
# 550           0        4.47      MN  1636498702

# %%
# HOTEL MAP 
# New variable name
hotels_df = filtered_weather_df

target_radius = 5000
target_type = "lodging"
hotels = []

# Parameteres
params = {
    "location": f"{lat}, {lng}",
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# iterrows to itterate through Pandas dataframe
for index,row in hotels_df.iterrows():
    
    #Get Latitude and Longitude from df 
    lat = row['Lat']
    lng = row['Lon']
    
    #Add location to params
    params['location'] = f"{lat}, {lng}"
    
    #assemble url and make API request
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    response = requests.get(base_url, params=params).json()
    
    #Extract results
    results= response['results']
    
    
    try: 
        print(f"The closest {target_type} Hotel is {results[0]['name']} in {row['City']}.")
        print(f"Located at: {params['location']}")
        #Add a 'Hotel' column to dataframe
        hotels_df.loc[index, 'Hotel']= results[0]['name']
        #hotel_dict = {
        #"Hotel": results[0]['name']
        #}
        #hotels.append(hotel_dict)
    #"Catching" an error to let the rest of the code run
    except (KeyError, IndexError):
        print("Missing field/result... skipping")
        
    print('-'*25)
# Out:
# The closest lodging Hotel is La orilla de auquinco in Teno.
# Located at: -34.8667, -71.1833
# -------------------------
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# The closest lodging Hotel is Observatory Guest House in Busselton.
# Located at: -33.65, 115.3333
# -------------------------
# The closest lodging Hotel is Albatros Hotel in Ushuaia.
# Located at: -54.8, -68.3
# -------------------------
# The closest lodging Hotel is Los Mosaicos in Vicuña.
# Located at: -30.0319, -70.7081
# -------------------------
# The closest lodging Hotel is Casa Maquia in Lata.
# Located at: 40.1629, -8.3327
# -------------------------
# Missing field/result... skipping
# -------------------------
# The closest lodging Hotel is Tu Casa in East London.
# Located at: -33.0153, 27.9116
# -------------------------
# The closest lodging Hotel is Southern Sun Waterfront Cape Town in Cape Town.
# Located at: -33.9258, 18.4232
# -------------------------
# The closest lodging Hotel is Broadwater Mariner Resort in Geraldton.
# Located at: -28.7667, 114.6
# -------------------------
# The closest lodging Hotel is Casa Laguna, Bed & Breakfast in Guerrero Negro.
# Located at: 27.9769, -114.0611
# -------------------------
# The closest lodging Hotel is Hotel Dreams Del Estrecho in Punta Arenas.
# Located at: -53.15, -70.9167
# -------------------------
# The closest lodging Hotel is Ekaant Hotel in Bakloh.
# Located at: 32.4667, 75.9167
# -------------------------
# The closest lodging Hotel is Nuba Nile in Aswān.
# Located at: 24.0934, 32.907
# -------------------------
# Missing field/result... skipping
# -------------------------
# The closest lodging Hotel is 39 On Nile Guest House in Port Elizabeth.
# Located at: -33.918, 25.5701
# -------------------------
# The closest lodging Hotel is Hotel San Isidro Oficial in Pisco.
# Located at: -13.7, -76.2167
# -------------------------
# The closest lodging Hotel is Hosteria Sampedro in Rawson.
# Located at: -43.3002, -65.1023
# -------------------------
# The closest lodging Hotel is دفتر پیشخوان دولت جمال زهی (خالد) in Khāsh.
# Located at: 28.2211, 61.2158
# -------------------------
# The closest lodging Hotel is Abbas Abad Hotel & Restaurant in Behshahr.
# Located at: 36.6923, 53.5526
# -------------------------
# Missing field/result... skipping
# -------------------------
# The closest lodging Hotel is Skytterhuset in Hammerfest.
# Located at: 70.6634, 23.6821
# -------------------------
# The closest lodging Hotel is Hotel Castillo in Villarrobledo.
# Located at: 39.2699, -2.6012
# -------------------------
# The closest lodging Hotel is Royal Garden Hotel in Jumla.
# Located at: 29.2747, 82.1838
# -------------------------
# The closest lodging Hotel is Austral Hotel in Comodoro Rivadavia.
# Located at: -45.8667, -67.5
# -------------------------
# The closest lodging Hotel is Fakhamat Al Orjoana Apartment in Sakakah.
# Located at: 29.9697, 40.2064
# -------------------------
# The closest lodging Hotel is Mingshihui Jinchang International Hotel in Jinchang.
# Located at: 38.4953, 102.1739
# -------------------------
# The closest lodging Hotel is Royal Park hotel & suites in Minna.
# Located at: 9.6139, 6.5569
# -------------------------
# The closest lodging Hotel is Baghdad Hotel in Baghdad.
# Located at: 33.3406, 44.4009
# -------------------------
# The closest lodging Hotel is Forte Oil - Old Lorry Park in Gashua.
# Located at: 12.870999999999999, 11.0482
# -------------------------
# The closest lodging Hotel is Laoyutang Resort in Kumul.
# Located at: 42.8, 93.45
# -------------------------
# Missing field/result... skipping
# -------------------------
# The closest lodging Hotel is Super 8 Hotel in Xuchang.
# Located at: 34.0167, 113.8167
# -------------------------
# The closest lodging Hotel is El sueño de Lampa I y II in Lampa.
# Located at: -33.2833, -70.9
# -------------------------
# The closest lodging Hotel is Rossio Hotel in Portalegre.
# Located at: 39.2938, -7.4312
# -------------------------
# The closest lodging Hotel is GreenTree Alliance Gansu Baiyin Renmin Road Hotel in Baiyin.
# Located at: 36.5583, 104.2081
# -------------------------
# The closest lodging Hotel is RAN Hotel Somketa in Bobo-Dioulasso.
# Located at: 11.1771, -4.2979
# -------------------------
# The closest lodging Hotel is Lindsey Hôtel in Saint-Pierre.
# Located at: -21.3393, 55.4781
# -------------------------
# The closest lodging Hotel is Hotel Morotin in Santa Maria.
# Located at: -29.6842, -53.8069
# -------------------------
# The closest lodging Hotel is Douro Palace Hotel Resort & Spa in Valadares.
# Located at: 41.1474, -7.9812
# -------------------------
# The closest lodging Hotel is Hotel Arena Gruesa in Ancud.
# Located at: -41.8697, -73.8203
# -------------------------
# The closest lodging Hotel is Renaissance Naples Hotel Mediterraneo in Naples.
# Located at: 40.8333, 14.25
# -------------------------
# The closest lodging Hotel is Hôtel All Suites Le Teich in Arrondissement d'Arcachon.
# Located at: 44.5875, -1.0519
# -------------------------
# The closest lodging Hotel is Zhangye Lvzhou Holiday Inn in Zhangye.
# Located at: 38.9342, 100.4517
# -------------------------
# The closest lodging Hotel is Rainforest Haven Inn in San Ignacio.
# Located at: 17.1561, -89.0714
# -------------------------
# The closest lodging Hotel is Hotel Santa Cruz in Río Gallegos.
# Located at: -51.6226, -69.2181
# -------------------------
# Missing field/result... skipping
# -------------------------
# The closest lodging Hotel is Jared Coffin House in Nantucket.
# Located at: 41.2835, -70.0995
# -------------------------
# The closest lodging Hotel is Enviro Villa in Maun.
# Located at: -19.9833, 23.4167
# -------------------------
# The closest lodging Hotel is Wanda Realm in Dongying.
# Located at: 37.4564, 118.4856
# -------------------------
# The closest lodging Hotel is The Blue Sky Hotel and Tower in Ulaanbaatar.
# Located at: 47.9077, 106.8832
# -------------------------

# %%
# Display new dataframe
hotels_df
# Out:
#                           City      Lat       Lon  Max Temp  Humidity  \
# 1                         Teno -34.8667  -71.1833     74.75        43
# 4                    Busselton -33.6500  115.3333     53.04        65
# 11                     Ushuaia -54.8000  -68.3000     65.86        34
# 19                      Vicuña -30.0319  -70.7081     73.78        49
# 30                        Lata  40.1629   -8.3327     56.05        73
# 35                 Provideniya  64.3833 -173.3000     19.51        73
# 36                 East London -33.0153   27.9116     60.19        85
# 39                   Cape Town -33.9258   18.4232     59.11        78
# 76                   Geraldton -28.7667  114.6000     54.12        94
# 98              Guerrero Negro  27.9769 -114.0611     68.16        66
# 114               Punta Arenas -53.1500  -70.9167     69.91        19
# 119                     Bakloh  32.4667   75.9167     53.91        28
# 120                      Aswān  24.0934   32.9070     76.30        22
# 142                   Kurisove  46.9695   30.9591     36.05        64
# 158             Port Elizabeth -33.9180   25.5701     53.89        94
# 163                      Pisco -13.7000  -76.2167     68.05        73
# 178                     Rawson -43.3002  -65.1023     60.04        42
# 195                      Khāsh  28.2211   61.2158     49.46        53
# 214                   Behshahr  36.6923   53.5526     53.73        42
# 247                      Saýat  38.7839   63.8803     35.47        73
# 252                 Hammerfest  70.6634   23.6821     27.05        74
# 282              Villarrobledo  39.2699   -2.6012     46.78        68
# 296                      Jumla  29.2747   82.1838     41.76        35
# 304         Comodoro Rivadavia -45.8667  -67.5000     84.06        18
# 305                    Sakakah  29.9697   40.2064     58.57        17
# 309                   Jinchang  38.4953  102.1739     28.17        40
# 314                      Minna   9.6139    6.5569     80.31        83
# 318                    Baghdad  33.3406   44.4009     55.31        41
# 333                     Gashua  12.8710   11.0482     81.59        16
# 341                      Kumul  42.8000   93.4500     25.23        56
# 344            Tiznit Province  29.5833   -9.5000     55.13        59
# 347                    Xuchang  34.0167  113.8167     49.08        46
# 349                      Lampa -33.2833  -70.9000     72.43        43
# 364                 Portalegre  39.2938   -7.4312     49.50        62
# 372                     Baiyin  36.5583  104.2081     14.88        34
# 381             Bobo-Dioulasso  11.1771   -4.2979     84.65        58
# 399               Saint-Pierre -21.3393   55.4781     73.08        66
# 406                Santa Maria -29.6842  -53.8069     74.50        43
# 421                  Valadares  41.1474   -7.9812     54.48        76
# 444                      Ancud -41.8697  -73.8203     62.13        76
# 459                     Naples  40.8333   14.2500     68.05        79
# 475  Arrondissement d'Arcachon  44.5875   -1.0519     37.72        93
# 485                    Zhangye  38.9342  100.4517     20.44        56
# 489                San Ignacio  17.1561  -89.0714     84.34        51
# 499               Río Gallegos -51.6226  -69.2181     84.25         5
# 532                     Tanout  14.9709    8.8879     82.58        15
# 539                  Nantucket  41.2835  -70.0995     56.97        90
# 541                       Maun -19.9833   23.4167     80.56        36
# 546                   Dongying  37.4564  118.4856     37.44        71
# 550                Ulaanbaatar  47.9077  106.8832      5.13        85
#
#      Cloudiness  Wind Speed Country        Date  \
# 1             0       10.36      CL  1636498342
# 4             0        8.25      AU  1636498343
# 11            0       17.27      AR  1636498349
# 19            0        5.30      CL  1636498354
# 30            0        3.22      PT  1636498363
# 35            0        4.47      RU  1636498367
# 36            0        8.14      ZA  1636498368
# 39            0        5.75      ZA  1636498283
# 76            0        5.75      AU  1636498394
# 98            0       21.81      MX  1636498408
# 114           0       14.97      CL  1636498203
# 119           0        7.20      IN  1636498420
# 120           0       11.50      EG  1636498420
# 142           0       12.68      UA  1636498434
# 158           0        3.44      ZA  1636498446
# 163           0       21.85      PE  1636498450
# 178           0       26.84      AR  1636498459
# 195           0        4.65      IR  1636498470
# 214           0        5.70      IR  1636498483
# 247           0        5.97      TM  1636498504
# 252           0        3.44      NO  1636498508
# 282           0        9.04      ES  1636498527
# 296           0        5.03      NP  1636498536
# 304           0       17.27      AR  1636498541
# 305           0        4.99      SA  1636498542
# 309           0        1.59      CN  1636498545
# 314           0        4.61      NG  1636498548
# 318           0        2.30      IQ  1636498466
# 333           0        8.61      NG  1636498559
# 341           0        5.17      CN  1636498565
# 344           0        0.81      MA  1636498567
# 347           0        9.51      CN  1636498569
# 349           0       16.11      CL  1636498569
# 364           0        4.50      PT  1636498578
# 372           0        2.28      CN  1636498584
# 381           0        4.61      BF  1636498508
# 399           0        4.61      RE  1636498600
# 406           0        6.91      BR  1636498605
# 421           0        4.50      PT  1636498615
# 444           0       12.41      CL  1636498630
# 459           0        5.99      IT  1636498478
# 475           0        2.30      FR  1636498650
# 485           0        1.79      CN  1636498657
# 489           0        6.91      BZ  1636498661
# 499           0       26.46      AR  1636498612
# 532           0        7.61      NE  1636498690
# 539           0       12.01      US  1636498695
# 541           0        4.61      BW  1636498696
# 546           0        9.80      CN  1636498700
# 550           0        4.47      MN  1636498702
#
#                                                  Hotel
# 1                                La orilla de auquinco
# 4                              Observatory Guest House
# 11                                      Albatros Hotel
# 19                                        Los Mosaicos
# 30                                         Casa Maquia
# 35                                                 NaN
# 36                                             Tu Casa
# 39                   Southern Sun Waterfront Cape Town
# 76                           Broadwater Mariner Resort
# 98                        Casa Laguna, Bed & Breakfast
# 114                          Hotel Dreams Del Estrecho
# 119                                       Ekaant Hotel
# 120                                          Nuba Nile
# 142                                                NaN
# 158                             39 On Nile Guest House
# 163                           Hotel San Isidro Oficial
# 178                                  Hosteria Sampedro
# 195                  دفتر پیشخوان دولت جمال زهی (خالد)
# 214                      Abbas Abad Hotel & Restaurant
# 247                                                NaN
# 252                                       Skytterhuset
# 282                                     Hotel Castillo
# 296                                 Royal Garden Hotel
# 304                                      Austral Hotel
# 305                      Fakhamat Al Orjoana Apartment
# 309            Mingshihui Jinchang International Hotel
# 314                          Royal Park hotel & suites
# 318                                      Baghdad Hotel
# 333                         Forte Oil - Old Lorry Park
# 341                                   Laoyutang Resort
# 344                                                NaN
# 347                                      Super 8 Hotel
# 349                           El sueño de Lampa I y II
# 364                                       Rossio Hotel
# 372  GreenTree Alliance Gansu Baiyin Renmin Road Hotel
# 381                                  RAN Hotel Somketa
# 399                                      Lindsey Hôtel
# 406                                      Hotel Morotin
# 421                    Douro Palace Hotel Resort & Spa
# 444                                 Hotel Arena Gruesa
# 459              Renaissance Naples Hotel Mediterraneo
# 475                          Hôtel All Suites Le Teich
# 485                         Zhangye Lvzhou Holiday Inn
# 489                               Rainforest Haven Inn
# 499                                   Hotel Santa Cruz
# 532                                                NaN
# 539                                 Jared Coffin House
# 541                                       Enviro Villa
# 546                                        Wanda Realm
# 550                       The Blue Sky Hotel and Tower

# %%
hotel_list = hotels_df["Hotel"].tolist()

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotels_df.iterrows()]

# Map Lat and Lon into locations
locations = hotels_df[["Lat", "Lon"]].astype(float)

# Marker_layer using
markers = gmaps.marker_layer(locations,
    info_box_content=hotel_info                          
)
fig.add_layer(markers)
# Display
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
